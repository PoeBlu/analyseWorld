# %%
import easygui as gui
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
filename=gui.fileopenbox()

# %%
df=pd.read_csv(filename)
df2=df.ix[:,5:10]

# %%
df.columns
# Out:
# Index([u'Timestamp', u'You are a ', u'You are a part of',
#        u'Your journey started', u'Please tick all relevant options',
#        u'Are you currently being paid?', u'If yes...',
#        u'If no, what is your financial situation',
#        u'How many people depend on your salary?',
#        u'Is the stipend sufficient?',
#        u'How often to you interact with your PI?',
#        u'Is the amount of interaction sufficient for you?',
#        u'How accessible is your PI?',
#        u'How candid/frank can you be with your PI in scientific discussions?',
#        u'How candid/frank can you be with your PI in general?',
#        u'How satisfied are you with the scientific interaction with your PI?',
#        u'How satisfied are you with the mentorship of your PI?',
#        u'Is there anything that you think would be beneficial for your interactions with your PI?',
#        u'How often do you have a TCM',
#        u'How useful is your TCM meeting and (feedback on) reports?',
# ...

# %%
df=df[df['You are a '].isin(['JRF', 'Externally Registered PhD Student', 'GS student','Post doc',])]
dfJour=df[(df['Your journey started']!='Left inStem. Not there anymore.') & (df['Your journey started']!='2016')]

# %%
g = sns.factorplot(hue='Your journey started',y='Is the stipend sufficient?', x="Are you currently being paid?",  data=dfJour,
                   col='You are a ',size=4, aspect=.7,kind='violin',
                   hue_order=['2017', '2015-2016', '2013-2014','2011-2012','Before 2010']);
# Out:
# <img src="data:image/png;base64,..." width="1120">

# %%
g = sns.factorplot(hue='Your journey started', x="Are you currently being paid?",  data=dfJour,
                   col='You are a ',kind="count",size=4, aspect=.7,
                   hue_order=['2017', '2015-2016', '2013-2014','2011-2012','Before 2010']);
# Out:
# <img src="data:image/png;base64,..." width="1120">

# %%
sns.countplot(hue='Your journey started', x="Are you currently being paid?",  data=dfJour)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
dfJour.groupby(['Are you currently being paid?','Your journey started',]).count()
# Out:
#                                                     Timestamp  You are a   \
# Are you currently being paid? Your journey started
# No                            2011-2012                    13          13
#                               2013-2014                     2           2
#                               2017                          1           1
#                               Before 2010                   2           2
#                               Prefer not to say.            1           1
# Yes                           2011-2012                    25          25
#                               2013-2014                    45          45
#                               2015-2016                    67          67
#                               2017                         34          34
#                               Before 2010                   7           7
#
#                                                     You are a part of  \
# ...

# %%
sns.

# %%
df.groupby(['Are you currently being paid?','If yes...','You are a ','Your journey started','Is the stipend sufficient?']).sum()
# Out:
#                                                                                                                                                                                                 How candid/frank can you be with your PI in scientific discussions?  \
# Are you currently being paid? If yes...                                          You are a                                          Your journey started            Is the stipend sufficient?
# No                            Has been waiting for fellowship from CSIR for l... JRF                                                2017                            2.0                                                                       5.0
#                               My CSIR funding always comes late. NCBS used to... GS student                                         2011-2012                       4.0                                                                       2.0
# ...

# %%
sns.countplot(df2['Are you currently being paid?'])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.columns
# Out:
# Index([u'Timestamp', u'You are a ', u'You are a part of',
#        u'Your journey started', u'Please tick all relevant options',
#        u'Are you currently being paid?', u'If yes...',
#        u'If no, what is your financial situation',
#        u'How many people depend on your salary?',
#        u'Is the stipend sufficient?',
#        u'How often to you interact with your PI?',
#        u'Is the amount of interaction sufficient for you?',
#        u'How accessible is your PI?',
#        u'How candid/frank can you be with your PI in scientific discussions?',
#        u'How candid/frank can you be with your PI in general?',
#        u'How satisfied are you with the scientific interaction with your PI?',
#        u'How satisfied are you with the mentorship of your PI?',
#        u'Is there anything that you think would be beneficial for your interactions with your PI?',
#        u'How often do you have a TCM',
#        u'How useful is your TCM meeting and (feedback on) reports?',
# ...

# %%
df[['Are you currently being paid?','If yes...','If no, what is your financial situation']]
# Out:
#     Are you currently being paid?
# 0                             Yes
# 1                             Yes
# 2                             Yes
# 3                             Yes
# 4                             Yes
# 5                             Yes
# 6                             Yes
# 7                             Yes
# 8                             Yes
# 9                             Yes
# 10                            Yes
# 11                            Yes
# 12                            Yes
# 13                             No
# 14                            Yes
# 15                            Yes
# 16                            Yes
# 17                            Yes
# 18                            Yes
# 19                            Yes
# 20                            Yes
# 21                            Yes
# 22                            Yes
# 23                            Yes
# 24                            Yes
# 25                            Yes
# ...

# %%
df.columns
# Out:
# Index([u'Timestamp', u'You are a ', u'You are a part of',
#        u'Your journey started', u'Please tick all relevant options',
#        u'Are you currently being paid?', u'If yes...',
#        u'If no, what is your financial situation',
#        u'How many people depend on your salary?',
#        u'Is the stipend sufficient?',
#        u'How often to you interact with your PI?',
#        u'Is the amount of interaction sufficient for you?',
#        u'How accessible is your PI?',
#        u'How candid/frank can you be with your PI in scientific discussions?',
#        u'How candid/frank can you be with your PI in general?',
#        u'How satisfied are you with the scientific interaction with your PI?',
#        u'How satisfied are you with the mentorship of your PI?',
#        u'Is there anything that you think would be beneficial for your interactions with your PI?',
#        u'How often do you have a TCM',
#        u'How useful is your TCM meeting and (feedback on) reports?',
# ...
